# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
IscVoc_8Ohm = pd.read_csv("IscVoc_8Ohm.csv")

# %%
IscVoc_8Ohm_array = IscVoc_8Ohm.to_numpy()

# %%
IscVoc_8Ohm
# Out:
#    Illumination   Jsc (mA/cm^2)   Voc(mV)     FF   Efficency
# 0             1           34.24     622.3  46.52       9.911
# 1             2           67.19     639.5  27.63       5.936
# 2             3           76.74     649.6  25.45       4.229
# 3             4           79.27     656.6  25.19       3.277
# 4             5           80.68     662.1  25.09       2.681

# %%
x = IscVoc_8Ohm_array[:,0]
jsc = IscVoc_8Ohm_array[:,1]
voc = IscVoc_8Ohm_array[:,2]

# %%
x,y
# Out:
# (array([1., 2., 3., 4., 5.]), array([34.24, 67.19, 76.74, 79.27, 80.68]))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Illumination (sun)')
ax1.set_ylabel('Jsc', color=color)
ax1.plot(x, jsc, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel('Voc', color=color) 
ax2.plot(x, voc, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
FF = IscVoc_8Ohm_array[:,3]
Eff = IscVoc_8Ohm_array[:,4]
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Illumination (sun)')
ax1.set_ylabel('FF', color=color)
ax1.plot(x, FF, color=color)
ax1.plot(x, Eff, color='tab:blue')

# %%
IscVoc_8Ohm = pd.read_csv("IscVoc_8Ohm.csv").to_numpy()
IscVoc_6Ohm = pd.read_csv("IscVoc_6Ohm.csv").to_numpy()
IscVoc_4Ohm = pd.read_csv("IscVoc_4Ohm.csv").to_numpy()
IscVoc_2Ohm = pd.read_csv("IscVoc_2Ohm.csv").to_numpy()
IscVoc_10Ohm = pd.read_csv("IscVoc_10Ohm.csv").to_numpy()

# %%
import numpy as np

# %%
data = np.stack([IscVoc_2Ohm,IscVoc_4Ohm,IscVoc_6Ohm,IscVoc_8Ohm,IscVoc_10Ohm])

# %%
r = np.arange(2,12,2)
ff_5Sun = data[:,4,3]
ff_4Sun = data[:,3,3]
ff_3Sun = data[:,2,3]
ff_2Sun = data[:,1,3]
ff_1Sun = data[:,0,3]

# %%
plt.plot(r,ff_4Sun,label = "FF_4Suns")
plt.plot(r,ff_3Sun,label = "FF_3Suns")
plt.plot(r,ff_2Sun,label = "FF_2Suns")
plt.plot(r,ff_1Sun,label = "FF_1Suns")
plt.plot(r,ff_5Sun,label = "FF_5Suns")
plt.legend()
plt.show()

# %%
IV_2 = pd.read_csv("IV_1Sun_2Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_4 = pd.read_csv("IV_1Sun_4Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_6 = pd.read_csv("IV_1Sun_6Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_8 = pd.read_csv("IV_1Sun_8Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_10 = pd.read_csv("IV_1Sun_10Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()

# %%
# Out:
#       v [V]   j [A/cm^2]   p [W/cm^2]
# 0  -0.100000     0.034246    -0.003425
# 1  -0.042857     0.034245    -0.001468
# 2   0.000000     0.034244     0.000000
# 3   0.014286     0.034244     0.000489
# 4   0.071429     0.034243     0.002446
# 5   0.128571     0.034242     0.004403
# 6   0.185714     0.034241     0.006359
# 7   0.242857     0.034239     0.008315
# 8   0.300000     0.034236     0.010271
# 9   0.357143     0.034219     0.012221
# 10  0.414286     0.034080     0.014119
# 12  0.467857     0.033091     0.015482
# 14  0.467857     0.033091     0.015482
# 11  0.471429     0.032937     0.015528
# 13  0.528571     0.026860     0.014198
# 15  0.585714     0.012387     0.007255
# 16  0.621875     0.000116     0.000072
# 17  0.642857    -0.007684    -0.004940
# 18  0.700000    -0.030543    -0.021380

# %%
I = -IV[:,1]
V = IV[:,0]

# %%
def PLOT(IV,label):
    I = -IV[:,1]
    V = IV[:,0]
    plt.plot(V,I,label = label)

# %%
PLOT(IV_2,label = "Rs=2ohm")
PLOT(IV_4,label = "Rs=4ohm")
PLOT(IV_6,label = "Rs=6ohm")
PLOT(IV_8,label = "Rs=8ohm")
PLOT(IV_10,label = "Rs=10ohm")
plt.legend()
plt.show()

# %%
IV_1 = pd.read_csv("IV_1Sun_4Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_2 = pd.read_csv("IV_2Sun_4Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_3 = pd.read_csv("IV_3Sun_4Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_4 = pd.read_csv("IV_4Sun_4Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()
IV_5 = pd.read_csv("IV_5Sun_4Ohm.csv",delimiter="\t").sort_values('v [V] ').to_numpy()

# %%
PLOT(IV_1,label = "1 Sun")
PLOT(IV_2,label = "2 Sun")
PLOT(IV_3,label = "3 Sun")
PLOT(IV_4,label = "4 Sun")
PLOT(IV_5,label = "5 Sun")
plt.legend()
plt.show()
